# %% [markdown]
# ### 7.1 ambient noise reduction
# 1. Divide the audio in frames of 25ms with hop length of 10ms.
# 2. Calculate the spectral centroids for each window. This is achieved by using the method features.spectral_centroid() of LibROSA.
# 3. Determine the maximum and minimum centroid value from the values calculated in the previous step. Let us call them the upper and lower thresholds respectively.
# 4. Apply a lowshelf filter for gain=-30 and frequency as the lower threshold. The lower threshold points towards the noisy part of the audio, and setting the gain to -30 significantly reduces those volumes which eventually helps in reducing those signals in the audio. Lesser gain reduces volume, eliminates insignificant noises.
# 5. Now, apply a highshelf filter for gain=-30 and higher threshold. This step is practically useful in reducing the foreground noises that might exist in the audio. For example, a person clapping close the mic between the speech of a person can be classified as a foreground noise.
# 6. To compensate for the volume loss in steps 4 and step 5, we apply limiter with a gain of +10 to increase the volume.

# %%
import numpy as np
import scipy.io.wavfile as wav
import os
import csv # create the datastet from the audio data
import matplotlib.pyplot as plt
import librosa as l
import IPython.display as ipd

# %%
# audio data foldel
check_folder = '../16000_pcm_speeches/Nelson_Mandela/'
print("tot files:", len(os.listdir(check_folder)))
os.listdir(check_folder)
# Out:
# tot files: 1500
# ['1452.wav',
#  '526.wav',
#  '880.wav',
#  '430.wav',
#  '1319.wav',
#  '1167.wav',
#  '902.wav',
#  '167.wav',
#  '1031.wav',
#  '592.wav',
#  '104.wav',
#  '1492.wav',
#  '1164.wav',
#  '941.wav',
#  '663.wav',
#  '710.wav',
#  '875.wav',
#  '99.wav',
#  '937.wav',
#  '1273.wav',
#  '525.wav',
#  '574.wav',
#  '1192.wav',
#  '1490.wav',
#  '1090.wav',
#  '513.wav',
#  '365.wav',
#  '148.wav',
#  '184.wav',
#  '900.wav',
#  '1487.wav',
#  '961.wav',
#  '529.wav',
#  '11.wav',
#  '1415.wav',
#  '1431.wav',
#  '985.wav',
#  '682.wav',
#  '121.wav',
#  '884.wav',
#  '654.wav',
#  '982.wav',
#  '516.wav',
#  '1253.wav',
#  '249.wav',
#  '1396.wav',
#  '1264.wav',
#  '1383.wav',
#  '1179.wav',
#  '832.wav',
#  '45.wav',
#  '1476.wav',
#  '290.wav',
#  '1281.wav',
#  '878.wav',
#  '5.wav',
#  '1000.wav',
#  '116.wav',
#  '1244.wav',
#  '1011.wav',
#  '822.wav',
#  '626.wav',
#  '1232.wav',
#  '888.wav',
#  '787.wav',
#  '1108.wav',
#  '1317.wav',
#  '1338.wav',
#  '1204.wav',
#  '244.wav',
#  '853.wav',
#  '1077.wav',
#  '958.wav',
#  '501.wav',
#  '348.wav',
#  '346.wav',
#  '535.wav',
#  '162.wav',
#  '398.wav',
#  '726.wav',
#  '425.wav',
#  '1328.wav',
#  '1251.wav',
#  '1287.wav',
#  '965.wav',
#  '1161.wav',
#  '211.wav',
#  '673.wav',
#  '1368.wav',
#  '810.wav',
#  '1407.wav',
#  '775.wav',
#  '730.wav',
#  '727.wav',
#  '341.wav',
#  '1373.wav',
#  '854.wav',
#  '613.wav',
#  '1469.wav',
#  '1121.wav',
#  '1449.wav',
#  '141.wav',
#  '337.wav',
#  '1344.wav',
#  '1499.wav',
#  '922.wav',
#  '977.wav',
#  '1200.wav',
#  '506.wav',
#  '1096.wav',
#  '247.wav',
#  '571.wav',
#  '1231.wav',
#  '376.wav',
#  '1488.wav',
#  '493.wav',
#  '260.wav',
#  '1446.wav',
#  '232.wav',
#  '1399.wav',
#  '665.wav',
#  '457.wav',
#  '695.wav',
#  '547.wav',
#  '1283.wav',
#  '1438.wav',
#  '761.wav',
#  '1099.wav',
#  '719.wav',
#  '772.wav',
#  '1409.wav',
#  '127.wav',
#  '204.wav',
#  '13.wav',
#  '964.wav',
#  '621.wav',
#  '1256.wav',
#  '762.wav',
#  '664.wav',
#  '754.wav',
#  '988.wav',
#  '839.wav',
#  '1017.wav',
#  '1430.wav',
#  '1237.wav',
#  '850.wav',
#  '725.wav',
#  '152.wav',
#  '358.wav',
#  '1363.wav',
#  '890.wav',
#  '1379.wav',
#  '27.wav',
#  '281.wav',
#  '1089.wav',
#  '992.wav',
#  '615.wav',
#  '1104.wav',
#  '798.wav',
#  '631.wav',
#  '1153.wav',
#  '650.wav',
#  '699.wav',
#  '309.wav',
#  '908.wav',
#  '969.wav',
#  '851.wav',
#  '490.wav',
#  '1154.wav',
#  '1427.wav',
#  '71.wav',
#  '201.wav',
#  '831.wav',
#  '1130.wav',
#  '118.wav',
#  '62.wav',
#  '352.wav',
#  '1384.wav',
#  '1081.wav',
#  '1265.wav',
#  '1174.wav',
#  '136.wav',
#  '806.wav',
#  '959.wav',
#  '1252.wav',
#  '1479.wav',
#  '776.wav',
#  '583.wav',
#  '1186.wav',
#  '14.wav',
#  '1302.wav',
#  '446.wav',
#  '361.wav',
#  '112.wav',
#  '677.wav',
#  '1120.wav',
#  '1178.wav',
#  '186.wav',
#  '1309.wav',
#  '234.wav',
#  '531.wav',
#  '817.wav',
#  '729.wav',
#  '20.wav',
#  '1072.wav',
#  '427.wav',
#  '608.wav',
#  '450.wav',
#  '1169.wav',
#  '1362.wav',
#  '731.wav',
#  '564.wav',
#  '544.wav',
#  '220.wav',
#  '1269.wav',
#  '366.wav',
#  '19.wav',
#  '1454.wav',
#  '299.wav',
#  '272.wav',
#  '589.wav',
#  '1327.wav',
#  '1398.wav',
#  '181.wav',
#  '236.wav',
#  '298.wav',
#  '1027.wav',
#  '580.wav',
#  '1434.wav',
#  '1291.wav',
#  '986.wav',
#  '466.wav',
#  '668.wav',
#  '837.wav',
#  '56.wav',
#  '194.wav',
#  '899.wav',
#  '778.wav',
#  '87.wav',
#  '1270.wav',
#  '122.wav',
#  '453.wav',
#  '363.wav',
#  '502.wav',
#  '1109.wav',
#  '283.wav',
#  '10.wav',
#  '687.wav',
#  '950.wav',
#  '598.wav',
#  '285.wav',
#  '766.wav',
#  '1496.wav',
#  '1275.wav',
#  '1095.wav',
#  '1475.wav',
#  '1416.wav',
#  '1356.wav',
#  '722.wav',
#  '395.wav',
#  '1220.wav',
#  '1060.wav',
#  '274.wav',
#  '1064.wav',
#  '895.wav',
#  '1004.wav',
#  '1355.wav',
#  '1102.wav',
#  '1152.wav',
#  '548.wav',
#  '495.wav',
#  '1286.wav',
#  '1486.wav',
#  '1022.wav',
#  '401.wav',
#  '150.wav',
#  '463.wav',
#  '387.wav',
#  '106.wav',
#  '981.wav',
#  '280.wav',
#  '1026.wav',
#  '79.wav',
#  '74.wav',
#  '17.wav',
#  '487.wav',
#  '1203.wav',
#  '250.wav',
#  '538.wav',
#  '579.wav',
#  '114.wav',
#  '607.wav',
#  '1267.wav',
#  '782.wav',
#  '451.wav',
#  '94.wav',
#  '1213.wav',
#  '1441.wav',
#  '619.wav',
#  '1426.wav',
#  '577.wav',
#  '97.wav',
#  '1417.wav',
#  '1304.wav',
#  '844.wav',
#  '1197.wav',
#  '545.wav',
#  '936.wav',
#  '369.wav',
#  '419.wav',
#  '1125.wav',
#  '221.wav',
#  '255.wav',
#  '492.wav',
#  '1339.wav',
#  '178.wav',
#  '1074.wav',
#  '448.wav',
#  '622.wav',
#  '77.wav',
#  '1284.wav',
#  '1312.wav',
#  '208.wav',
#  '63.wav',
#  '1489.wav',
#  '149.wav',
#  '254.wav',
#  '173.wav',
#  '1290.wav',
#  '1211.wav',
#  '268.wav',
#  '744.wav',
#  '786.wav',
#  '1157.wav',
#  '324.wav',
#  '1298.wav',
#  '342.wav',
#  '1212.wav',
#  '190.wav',
#  '755.wav',
#  '264.wav',
#  '53.wav',
#  '185.wav',
#  '1289.wav',
#  '616.wav',
#  '219.wav',
#  '489.wav',
#  '868.wav',
#  '649.wav',
#  '174.wav',
#  '602.wav',
#  '670.wav',
#  '823.wav',
#  '1366.wav',
#  '739.wav',
#  '49.wav',
#  '90.wav',
#  '1391.wav',
#  '1421.wav',
#  '322.wav',
#  '302.wav',
#  '758.wav',
#  '415.wav',
#  '1049.wav',
#  '325.wav',
#  '1112.wav',
#  '18.wav',
#  '1463.wav',
#  '1156.wav',
#  '1016.wav',
#  '227.wav',
#  '927.wav',
#  '43.wav',
#  '894.wav',
#  '1422.wav',
#  '39.wav',
#  '540.wav',
#  '314.wav',
#  '381.wav',
#  '252.wav',
#  '235.wav',
#  '1210.wav',
#  '464.wav',
#  '205.wav',
#  '1029.wav',
#  '1239.wav',
#  '458.wav',
#  '367.wav',
#  '339.wav',
#  '1181.wav',
#  '563.wav',
#  '1078.wav',
#  '648.wav',
#  '523.wav',
#  '1240.wav',
#  '1114.wav',
#  '555.wav',
#  '925.wav',
#  '1402.wav',
#  '948.wav',
#  '1361.wav',
#  '343.wav',
#  '78.wav',
#  '225.wav',
#  '931.wav',
#  '1353.wav',
#  '123.wav',
#  '312.wav',
#  '702.wav',
#  '1318.wav',
#  '372.wav',
#  '732.wav',
#  '491.wav',
#  '98.wav',
#  '364.wav',
#  '566.wav',
#  '209.wav',
#  '834.wav',
#  '774.wav',
#  '1155.wav',
#  '1148.wav',
#  '284.wav',
#  '1460.wav',
#  '575.wav',
#  '929.wav',
#  '125.wav',
#  '455.wav',
#  '704.wav',
#  '441.wav',
#  '1288.wav',
#  '811.wav',
#  '210.wav',
#  '437.wav',
#  '1314.wav',
#  '980.wav',
#  '357.wav',
#  '504.wav',
#  '1248.wav',
#  '200.wav',
#  '532.wav',
#  '521.wav',
#  '1360.wav',
#  '64.wav',
#  '898.wav',
#  '573.wav',
#  '1033.wav',
#  '891.wav',
#  '1448.wav',
#  '271.wav',
#  '576.wav',
#  '675.wav',
#  '1075.wav',
#  '769.wav',
#  '781.wav',
#  '145.wav',
#  '714.wav',
#  '585.wav',
#  '637.wav',
#  '233.wav',
#  '433.wav',
#  '681.wav',
#  '1397.wav',
#  '393.wav',
#  '671.wav',
#  '857.wav',
#  '1085.wav',
#  '1358.wav',
#  '1282.wav',
#  '1014.wav',
#  '1456.wav',
#  '485.wav',
#  '126.wav',
#  '497.wav',
#  '752.wav',
#  '69.wav',
#  '1354.wav',
#  '494.wav',
#  '499.wav',
#  '1458.wav',
#  '788.wav',
#  '953.wav',
#  '916.wav',
#  '768.wav',
#  '1051.wav',
#  '814.wav',
#  '1222.wav',
#  '12.wav',
#  '329.wav',
#  '397.wav',
#  '166.wav',
#  '50.wav',
#  '83.wav',
#  '353.wav',
#  '1285.wav',
#  '558.wav',
#  '551.wav',
#  '1138.wav',
#  '1216.wav',
#  '709.wav',
#  '983.wav',
#  '1254.wav',
#  '906.wav',
#  '117.wav',
#  '326.wav',
#  '1413.wav',
#  '1423.wav',
#  '293.wav',
#  '1365.wav',
#  '1301.wav',
#  '641.wav',
#  '1187.wav',
#  '151.wav',
#  '1194.wav',
#  '708.wav',
#  '549.wav',
#  '37.wav',
#  '424.wav',
#  '636.wav',
#  '1293.wav',
#  '30.wav',
#  '318.wav',
#  '690.wav',
#  '1040.wav',
#  '966.wav',
#  '639.wav',
#  '110.wav',
#  '1170.wav',
#  '1406.wav',
#  '1198.wav',
#  '105.wav',
#  '877.wav',
#  '378.wav',
#  '1218.wav',
#  '820.wav',
#  '266.wav',
#  '9.wav',
#  '1136.wav',
#  '1444.wav',
#  '295.wav',
#  '1221.wav',
#  '1184.wav',
#  '374.wav',
#  '1436.wav',
#  '784.wav',
#  '229.wav',
#  '510.wav',
#  '1063.wav',
#  '1150.wav',
#  '957.wav',
#  '240.wav',
#  '332.wav',
#  '1175.wav',
#  '496.wav',
#  '1118.wav',
#  '833.wav',
#  '1015.wav',
#  '1100.wav',
#  '955.wav',
#  '737.wav',
#  '887.wav',
#  '600.wav',
#  '241.wav',
#  '669.wav',
#  '656.wav',
#  '647.wav',
#  '522.wav',
#  '1481.wav',
#  '1277.wav',
#  '1403.wav',
#  '748.wav',
#  '1278.wav',
#  '767.wav',
#  '417.wav',
#  '460.wav',
#  '130.wav',
#  '1005.wav',
#  '305.wav',
#  '153.wav',
#  '1491.wav',
#  '1482.wav',
#  '323.wav',
#  '41.wav',
#  '32.wav',
#  '1249.wav',
#  '646.wav',
#  '1046.wav',
#  '1044.wav',
#  '1009.wav',
#  '904.wav',
#  '508.wav',
#  '1131.wav',
#  '159.wav',
#  '301.wav',
#  '1262.wav',
#  '590.wav',
#  '191.wav',
#  '858.wav',
#  '29.wav',
#  '308.wav',
#  '1116.wav',
#  '292.wav',
#  '1395.wav',
#  '915.wav',
#  '1142.wav',
#  '791.wav',
#  '15.wav',
#  '706.wav',
#  '507.wav',
#  '59.wav',
#  '812.wav',
#  '999.wav',
#  '1054.wav',
#  '892.wav',
#  '42.wav',
#  '1062.wav',
#  '838.wav',
#  '797.wav',
#  '645.wav',
#  '635.wav',
#  '792.wav',
#  '1389.wav',
#  '213.wav',
#  '179.wav',
#  '154.wav',
#  '404.wav',
#  '912.wav',
#  '874.wav',
#  '876.wav',
#  '1007.wav',
#  '306.wav',
#  '691.wav',
#  '1228.wav',
#  '237.wav',
#  '1352.wav',
#  '1497.wav',
#  '795.wav',
#  '1478.wav',
#  '263.wav',
#  '553.wav',
#  '403.wav',
#  '750.wav',
#  '794.wav',
#  '867.wav',
#  '568.wav',
#  '807.wav',
#  '238.wav',
#  '572.wav',
#  '307.wav',
#  '1008.wav',
#  '355.wav',
#  '1243.wav',
#  '354.wav',
#  '601.wav',
#  '712.wav',
#  '1435.wav',
#  '735.wav',
#  '414.wav',
#  '627.wav',
#  '1067.wav',
#  '1177.wav',
#  '1305.wav',
#  '674.wav',
#  '270.wav',
#  '881.wav',
#  '685.wav',
#  '410.wav',
#  '119.wav',
#  '469.wav',
#  '436.wav',
#  '667.wav',
#  '422.wav',
#  '696.wav',
#  '1364.wav',
#  '1129.wav',
#  '172.wav',
#  '1347.wav',
#  '7.wav',
#  '749.wav',
#  '997.wav',
#  '192.wav',
#  '840.wav',
#  '1215.wav',
#  '805.wav',
#  '479.wav',
#  '530.wav',
#  '1260.wav',
#  '910.wav',
#  '1035.wav',
#  '841.wav',
#  '1297.wav',
#  '765.wav',
#  '1404.wav',
#  '1473.wav',
#  '642.wav',
#  '956.wav',
#  '584.wav',
#  '1165.wav',
#  '25.wav',
#  '1133.wav',
#  '80.wav',
#  '932.wav',
#  '790.wav',
#  '333.wav',
#  '534.wav',
#  '848.wav',
#  '926.wav',
#  '482.wav',
#  '1378.wav',
#  '511.wav',
#  '561.wav',
#  '1257.wav',
#  '552.wav',
#  '338.wav',
#  '1066.wav',
#  '1101.wav',
#  '286.wav',
#  '379.wav',
#  '1143.wav',
#  '438.wav',
#  '169.wav',
#  '883.wav',
#  '484.wav',
#  '599.wav',
#  '176.wav',
#  '1369.wav',
#  '724.wav',
#  '371.wav',
#  '171.wav',
#  '1073.wav',
#  '518.wav',
#  '52.wav',
#  '1259.wav',
#  '861.wav',
#  '505.wav',
#  '72.wav',
#  '426.wav',
#  '554.wav',
#  '640.wav',
#  '1472.wav',
#  '408.wav',
#  '1336.wav',
#  '321.wav',
#  '816.wav',
#  '102.wav',
#  '21.wav',
#  '265.wav',
#  '952.wav',
#  '278.wav',
#  '1320.wav',
#  '624.wav',
#  '1224.wav',
#  '1424.wav',
#  '1351.wav',
#  '760.wav',
#  '1059.wav',
#  '1380.wav',
#  '248.wav',
#  '349.wav',
#  '1279.wav',
#  '144.wav',
#  '435.wav',
#  '913.wav',
#  '1247.wav',
#  '1048.wav',
#  '871.wav',
#  '707.wav',
#  '689.wav',
#  '661.wav',
#  '987.wav',
#  '1163.wav',
#  '1190.wav',
#  '741.wav',
#  '604.wav',
#  '920.wav',
#  '161.wav',
#  '828.wav',
#  '825.wav',
#  '1411.wav',
#  '416.wav',
#  '1093.wav',
#  '1209.wav',
#  '975.wav',
#  '6.wav',
#  '944.wav',
#  '773.wav',
#  '1180.wav',
#  '1346.wav',
#  '799.wav',
#  '147.wav',
#  '396.wav',
#  '855.wav',
#  '330.wav',
#  '91.wav',
#  '1106.wav',
#  '859.wav',
#  '666.wav',
#  '1019.wav',
#  '753.wav',
#  '246.wav',
#  '625.wav',
#  '1166.wav',
#  '452.wav',
#  '1451.wav',
#  '108.wav',
#  '918.wav',
#  '716.wav',
#  '1372.wav',
#  '1018.wav',
#  '277.wav',
#  '1261.wav',
#  '1070.wav',
#  '1442.wav',
#  '896.wav',
#  '911.wav',
#  '1158.wav',
#  '259.wav',
#  '132.wav',
#  '477.wav',
#  '1219.wav',
#  '89.wav',
#  '331.wav',
#  '1141.wav',
#  '88.wav',
#  '1292.wav',
#  '1268.wav',
#  '1464.wav',
#  '533.wav',
#  '31.wav',
#  '1207.wav',
#  '578.wav',
#  '515.wav',
#  '164.wav',
#  '389.wav',
#  '1419.wav',
#  '434.wav',
#  '947.wav',
#  '183.wav',
#  '1425.wav',
#  '1471.wav',
#  '251.wav',
#  '701.wav',
#  '528.wav',
#  '1080.wav',
#  '991.wav',
#  '643.wav',
#  '447.wav',
#  '1465.wav',
#  '1467.wav',
#  '1357.wav',
#  '882.wav',
#  '1235.wav',
#  '1092.wav',
#  '885.wav',
#  '68.wav',
#  '1071.wav',
#  '559.wav',
#  '187.wav',
#  '951.wav',
#  '1234.wav',
#  '703.wav',
#  '196.wav',
#  '51.wav',
#  '411.wav',
#  '1295.wav',
#  '242.wav',
#  '541.wav',
#  '1115.wav',
#  '216.wav',
#  '907.wav',
#  '360.wav',
#  '879.wav',
#  '1084.wav',
#  '320.wav',
#  '33.wav',
#  '993.wav',
#  '442.wav',
#  '509.wav',
#  '644.wav',
#  '1315.wav',
#  '28.wav',
#  '1159.wav',
#  '373.wav',
#  '1024.wav',
#  '128.wav',
#  '1012.wav',
#  '1176.wav',
#  '949.wav',
#  '36.wav',
#  '16.wav',
#  '796.wav',
#  '1202.wav',
#  '802.wav',
#  '156.wav',
#  '542.wav',
#  '444.wav',
#  '1474.wav',
#  '763.wav',
#  '70.wav',
#  '628.wav',
#  '603.wav',
#  '827.wav',
#  '866.wav',
#  '57.wav',
#  '733.wav',
#  '84.wav',
#  '1242.wav',
#  '1306.wav',
#  '476.wav',
#  '275.wav',
#  '1030.wav',
#  '623.wav',
#  '1229.wav',
#  '377.wav',
#  '736.wav',
#  '1122.wav',
#  '1132.wav',
#  '780.wav',
#  '282.wav',
#  '808.wav',
#  '1162.wav',
#  '92.wav',
#  '133.wav',
#  '1034.wav',
#  '1493.wav',
#  '400.wav',
#  '1443.wav',
#  '231.wav',
#  '1408.wav',
#  '261.wav',
#  '1484.wav',
#  '47.wav',
#  '1149.wav',
#  '756.wav',
#  '923.wav',
#  '1348.wav',
#  '370.wav',
#  '1470.wav',
#  '1258.wav',
#  '413.wav',
#  '1313.wav',
#  '620.wav',
#  '1068.wav',
#  '862.wav',
#  '872.wav',
#  '203.wav',
#  '224.wav',
#  '967.wav',
#  '38.wav',
#  '1128.wav',
#  '4.wav',
#  '519.wav',
#  '111.wav',
#  '1428.wav',
#  '1274.wav',
#  '1308.wav',
#  '1401.wav',
#  '1126.wav',
#  '539.wav',
#  '1137.wav',
#  '1418.wav',
#  '751.wav',
#  '614.wav',
#  '1236.wav',
#  '524.wav',
#  '694.wav',
#  '1041.wav',
#  '256.wav',
#  '1271.wav',
#  '680.wav',
#  '785.wav',
#  '683.wav',
#  '618.wav',
#  '720.wav',
#  '273.wav',
#  '928.wav',
#  '26.wav',
#  '262.wav',
#  '245.wav',
#  '182.wav',
#  '843.wav',
#  '617.wav',
#  '557.wav',
#  '54.wav',
#  '212.wav',
#  '560.wav',
#  '1483.wav',
#  '588.wav',
#  '777.wav',
#  '304.wav',
#  '789.wav',
#  '783.wav',
#  '1390.wav',
#  '500.wav',
#  '180.wav',
#  '672.wav',
#  '849.wav',
#  '1340.wav',
#  '905.wav',
#  '565.wav',
#  '745.wav',
#  ...]

# %%
ipd.Audio(check_folder+'100.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
signal, sample_rate = l.load(check_folder+'100.wav', sr=16000) # you are sure of sampling rate info
centroids = l.feature.spectral_centroid(y=signal, sr=sample_rate, n_fft=int(0.025*sample_rate),
                                       hop_length=int(0.010*sample_rate))
np_centroids = np.asarray(centroids)
print(np_centroids.shape)
np_centroids
# Out:
# (1, 101)
# array([[3109.18363404, 3189.68301633, 3244.68667144, 3220.97288085,
#         2883.12447593, 3185.49910855, 3426.42474383, 3329.62831332,
#         3044.33695671, 3011.06633899, 3116.29153304, 2992.03922153,
#         3168.05045582, 2980.90646335, 3279.81962601, 3648.69779067,
#         3183.55472994, 3219.6102842 , 3064.8098304 , 2931.34704378,
#         2889.25926418, 2650.56001271, 2813.38485301, 3128.82727447,
#         2927.21903632, 3243.2022362 , 2945.41040867, 3283.34237844,
#         3380.17751119, 2894.92271967, 2135.48333826, 2331.7601793 ,
#         1482.44002686, 2740.14172514, 1516.32262188, 1516.66087416,
#         1270.92192316, 1260.59479278, 1261.93356681, 1067.39678439,
#          904.08673391,  910.85405123, 1028.25624718, 1143.91927496,
#          904.06378312, 1028.56502367,  918.34864778,  844.36614839,
#         1070.62060222, 1033.01620033, 1127.94440592, 1498.87823837,
#         1820.65220441, 2102.36190901, 2032.52731941, 2045.39086577,
#         2092.19343524, 2290.87022895, 2476.66183688, 2211.35843301,
#         2010.00738659, 2263.65765678, 2186.25097095, 1788.89315062,
#         1325.18658798, 1488.60985992, 1344.14467715, 1889.10926941,
#         1957.49491785, 2034.16181295, 4427.30627287, 4597.46047024,
#         2357.95377866, 2539.61552337, 2665.67515004, 2817.06877266,
#         2250.47483308, 2690.23608096, 2752.52360999, 2426.87266441,
#         2251.41373585, 1857.46046714, 1325.5692286 , 1328.44059198,
#         1258.08803529, 1289.01276094, 1327.06423753, 1218.7335692 ,
#         1342.58605442, 1461.84883465, 1680.93414767, 1532.41538826,
#         1819.32688299, 2273.85030771, 1908.16462548, 2175.6224868 ,
#         2357.35575641, 2240.28923732, 1967.34444433, 2032.90911858,
#         1897.79839236]])

# %%
lower_th = np.min(centroids)
upper_th = np.max(centroids)
print("centroid min:", lower_th, "\tmax:", upper_th)
# Out:
# centroid min: 844.3661483864162 	max: 4597.460470244332

# %% [markdown]
# ### 7.2. Vocal Enhancement
# Unlike ambient noise, vocal and voice signals are the features that we want our feature
# extraction phase to focus more on. These are the significant parts of the audio that we wish to use
# to extract features from and build machine learning classifiers. Hence, enhancing these parts of the
# audio can greatly increase our accuracies. We can do this by using the concepts of MFCCs again.
# Following are the steps we took to enhance the vocal enhancements.
# 1. Divide the audio in frames of 25ms with a hop length of 10ms.
# 2. Calculate the MFCC coefficients for each frame.
# 3. *Take the sum of squares of MFCC.* Squaring the coefficients greatly helps in summarizing the spread of data. Additionally, MFCCs might not always be positive, squaring makes sure that all comparisons are made in the positive space of numbers. Although this can be achieved by absolute values too, squaring helps in summarizing the spread in a better way.
# 4. Find the strongest frame. The strongest frame is the frame which has the maximum sum of squares for its MFCCs. The reason for taking the strongest frame is that would indicate a certain vocal utterance. This is because we do this step after ambient noise removal, which reduces the foreground noise too, and hence the strongest frame now will most likely be the vocal part of the audio.
# 5. Find the minimum hertz value from the strongest frame and apply a lowshelf filter of a positive to gain to enhance those vocals.

# %%
basta fare la somma dei quadrati...

# %% [markdown]
# ### 7.3. Audio Trimming
# Audio trimming is another important pre-processing step to ensure that the audio is clean,
# improved, and more suitable for research. We have discussed in this report earlier that why audio
# trimming is needed and how it affects the quality. For the purpose of this research, we set the
# threshold value of 20 decibels. If a sound is less than this threshold, we consider it as silence and
# trim if it is a part of the edge. Using LibROSA’s lib.effects.trim() method, we achieve this goal of
# trimming the audio edges. We kept the frame length as 2048 and the hop length as 500 which
# signifies the number of samples between neighboring frames.

# %%
trim_signal = l.effects.trim(y=signal, top_db=20)

# %% [markdown]
# ### 7.4. Audio Splitting
# Similar to audio trimming, audio splitting is a technique used to reduce the unwanted parts
# in an audio. Trimming and splitting follow very similar fundamentals. Audio trimming is the
# process of reducing unwanted or silent parts from the start and end of an audio, whereas audio
# splitting takes this a step ahead and removes silences even from the middle portions of the audio.
